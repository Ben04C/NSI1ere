# %% [markdown]
# # TP -  Codage des caractères (2)

# %% [markdown]
# ***Comme le dit Confucius :"«  J'entends et j'oublie, Je vois et je me souviens, Je fais et je comprends. »"***

# %% [markdown]
# Écrire votre nom ici :
#
# Nom :
#
# Classe :

# %% [markdown]
# # Le chiffre de César
#
# Le chiffre de César est une méthode de chiffrement consistant à décaler les lettres de l'alphabet de quelques crans. Par exemple, si on décale les lettres de 3 rangs (comme le faisait Jules César)
# <p align="center">
# <img src="https://isn-icn-ljm.pagesperso-orange.fr//images/chiffre_cesar.PNG">
#   </p>

# %% [markdown]
# ## L'objectif
#
# En vous inspirant du TP-codage des caractères(1)
#
#
#
# * <font color="blue">Écrivez un programme Python qui implémente le chiffre de César. Utilisez pour cela les fonctions ord() et chr() .</font>
#
# * <font color="blue">On doit pouvoir choisir le décalage des lettres entre 1 et 25.</font>
#
# * <font color="blue">L'entrée sera un texte quelconque <u> sans accents et sans ponctuation</u> ; par contre, le texte d'entrée sera composé de majuscules et de minuscules.</font>
#
# * <font color="blue">Le texte de sortie sera écrit tout en majuscules.</font>
#
# * <font color="blue">Les espaces du texte d'entrée se retrouveront aux mêmes endroits dans le texte chiffré.</font>
#
# * <font color="blue">Faites en sorte que l'on puisse crypter, mais aussi décrypter un message.</font>
#
#
# ### Une aide...
#
# Les lettres majuscules sont sur la plage 65 (pour A) à 90 (pour Z)
#
# **La notion de "modulo"**
#
# Considérons les nombres de $0$ à $25$, il y en a $26$
#
# Lorsqu'on divise un nombre par 26, les restes possibles sont compris entre $0$ et $25$
#
# **Par exemple :**
# * Dans la division Euclidienne de $17$ par $26$ le reste est $ 17$
# * Dans la division Euclidienne de $28$ par $26$ le reste est $ 2$
#
# **En Python : l'opération  28%26 donne 2 comme résultat**
#
# **Elle se lit :**
# * **28 donne 2 modulo 26**
# * **Ou bien 28 est congru à 2 modulo 26**
# * **Ou bien 28 et 2 ont même reste dans la division Euclidienne par 26**
#
# Pour ramener les lettres de l'alphabet sur la plage $[0 ,1,2,...,25]$, il suffit de retirer $65$ au code ASCII de la lettre
#
# Cette opération permet de considérer que les nombres associés aux lettres de l'alphabet vont de $0$ à $25$
#
# ### Appliquons cela au chiffrement de César
#
# ***Comment se code la lettre $C$ :***
#
# * Le code ASCII de $C$ est $67$
# * On retire $65$, on trouve $2$
# * On applique le décalage de César : on trouve $5$
# * On calcule le reste dans la division Euclidienne de $5$ par $26$ : On trouve $5$
# * On ajoute $65$, on trouve $70$
# * On transforme ce code ASCII en lettre : $chr(70)$ , on trouve $F$
#
# **Comment se code la lettre $Y$ :**
#
#
# * Le code ASCII de $Y$ est $89$
# * On retire $65$, on trouve $24$
# * On applique le décalage de César : on trouve $27$
# * On calcule le reste dans la division Euclidienne de $27$ par $26$ : On trouve $1$
# * On ajoute $65$, on trouve $66$
# * On transforme ce code ASCII en lettre : $chr(66)$ , on trouve $B$

# %% [markdown]
# ### À faire :
# **Réaliser l'objectif**

# %%
#Écrire le code ici
#encode
def code_de_cesar(charinput, codeinput):
    """
    La fonction code_de_césar prends en premier argument une chaine de carracteres 
    et en 2emme la clé pour le code de César
    
    """
    assert codeinput>=1 and codeinput<=25, "Il faut mettre une clé qui est comprise entre 1 et 25 inclus"
    assert len(charinput)>=1, "Il faut entrer un message"
    charinput=charinput.upper()
    charoutput=""
    #conversion with "-" opperator
    for car in charinput:
        if car==" ":
            charoutput+=car
        else:
            temp=ord(car)-65+codeinput
            temp=temp%26
            temp+=65
            charoutput+=chr(temp)
            temp=0
    #return        
    print("Le code de césar avec une clé de", codeinput, 'est: "', charoutput, '" le message originel était', charinput)
    return charoutput
   


#decode
def decode_de_cesar(chardecode, decodekey):
    """
    La fonction decode_de_cesar prends en premier argument une chaine de carracteres 
    et en 2emme la clé décoder le code de César
    
    """
    assert decodekey>=1 and decodekey<=25, "Il faut mettre une clé qui est comprise entre 1 et 25 inclus"
    assert len(chardecode)>=1, "Il faut entrer un message"
    chardecode=chardecode.upper()
    decodeoutput=""
    #conversion with "+" opperator
    for car in chardecode:
        if car==" ":
            decodeoutput+=car
        else:
            temp=ord(car)-65-decodekey
            temp=temp%26
            temp+=65
            decodeoutput+=chr(temp)
            temp=0
    print('Le message originel est ',chardecode,"la clé est de",decodekey,'Le message décodé est ',decodeoutput)
    return chardecode
        
        
        
#initialisation
        
def init():
    """
    Permet d'initialiser le code et de faire un choix entre la fonction encode et decode
    """
    choixtemp=""
    
    choixtemp=input("Pour décoder entrez decode et pour encoder entrez encode ")
    print(choixtemp)
    if choixtemp=="encode":
        encode()
    elif choixtemp=="decode":
        decode()
    else:
        print("Erreur à l'initialisation")


def encode():
    """
    Permet de demander les variables avec "input" pour la variable "code_de_cesar"
    """
    inputtemp=input("Entrez votre message ")
    inputtemp2=int(input("Entrez la clé du code de César "))

    code_de_cesar(inputtemp, inputtemp2)
def decode():
    """
    Permet de demander les variables avec "input" pour la variable "decode_de_cesar"
    """
    inputtemp=input("Entrez votre message ")
    inputtemp2=int(input("Entrez la clé du code de César "))
    
    decode_de_cesar(inputtemp, inputtemp2)
    
    
init()
# Out:
# Pour décoder entrez decode et pour encoder entrez encode decode
# decode
# Entrez votre message KHOOR ZRUOG
# Entrez la clé du code de César 3
# Le message originel est  KHOOR ZRUOG la clé est de 3 Le message décodé est  HELLO WORLD

# %% [markdown]
# #ne pas utiliser
# def decode_de_cesar(chardecode, decodekey):
#     """
#     La fonction decode_de_cesar prends en premier argument une chaine de carracteres
#     et en 2emme la clé décoder le code de César
#
#     """
#     assert charcode>=1 and charcode<=25, "Il faut mettre une clé qui est comprise entre 1 et 25 inclus"
#     assert len(decodekey)>=1, "Il faut entrer un message"
#     chardecode=chardecode.upper()
#     decodeoutput=""
#     for car in chardecode:
#         if car==" ":
#             decodeoutput+=car
#         else:
#             temp=ord(car)-65-codeinput
#             temp=temp%26
#             temp+=65
#             decodeoutput+=chr(temp)
#             temp=0
#         print('Le message originel est "',chardecode,"la clé est de",decodekey,'Le message décodé est "',decodeoutput,'"')

# %% [markdown]
# #ne pas utiliser
# def init():
#     choixtemp=""
#
#     choixtemp=input("Pour décoder entrez decode et pour encoder entrez encode ")
#     print(choixtemp)
#     if choixtemp=="encode":
#         encode()
#     elif choixtemp=="decode":
#         decode()
#     else:
#         print("Erreur à l'initialisation")
#
#
# def encode():
#     inputtemp=input("Entrez votre message ")
#     inputtemp2=int(input("Entrez la clé du code de César "))
#
#     code_de_cesar(inputtemp, inputtemp2)
# def decode():
#     inputtemp=input("Entrez votre message ")
#     inputtemp2=int(input("Entrez la clé du code de César "))
#
#     decode_decesar(inputtemp, inputtemp2)
#
#
# init()
